# %% [markdown]
# <a href="https://colab.research.google.com/github/hecfrantuis/Proyecto-IA-1/blob/main/Proyecto_AcneI_A1_Descarga_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Drive - Librerias

# %%
#@title Montar el drive
import os
from google.colab import drive

Ubicacion = "Septimo/IA 1 2026-1/Proyecto" #@param {type:"string"}
path = "/content/drive/My Drive/" + Ubicacion
drive.mount('/content/drive')
os.chdir(path)
print(os.getcwd())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/Septimo/IA 1 2026-1/Proyecto

# %%
# @title Librerias
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# # Descarga del dataset

# %%
# @title Ubicacion para descargar el dataset
# Creamos la carpeta si no existe
if not os.path.exists(path):
    os.makedirs(path)
    print(f"Carpeta creada en: {path}")

# Nos movemos a esa ubicación
# %cd $path
# Out:
# /content

# %%
# @title Credenciales de Kaggle

KAGGLE_USERNAME = "hjfuis" #@param {type:"string"}
KAGGLE_KEY = "KGAT_7067e701e235e3e2e8508df6820a675d" #@param {type:"string"}
os.environ['KAGGLE_USERNAME'] = KAGGLE_USERNAME
os.environ['KAGGLE_KEY'] = KAGGLE_KEY

# Esto crea el archivo automáticamente en la ubicación correcta
# !mkdir -p ~/.kaggle
import json
data = {"username":os.environ['KAGGLE_USERNAME'], "key":os.environ['KAGGLE_KEY']}
with open('/root/.kaggle/kaggle.json', 'w') as f:
    json.dump(data, f)

# !chmod 600 /root/.kaggle/kaggle.json
print("Archivo kaggle.json creado exitosamente.")
# Out:
# Archivo kaggle.json creado exitosamente.

# %%
# @title Descargar y descomprimir el dataset
# !mkdir -p "$path"
# %cd "$path"

# Descarga el dataset desde Kaggle
# !kaggle datasets download -d tiswan14/acne-dataset-image

# Descomprime (el parámetro -q lo hace en silencio y más rápido)
# !unzip -q acne-dataset-image.zip
# !rm acne-dataset-image.zip  # Borra el zip para ahorrar espacio en Drive
print("¡Hecho! Los archivos están en tu Drive.")
# Out:
# /content
# Dataset URL: https://www.kaggle.com/datasets/tiswan14/acne-dataset-image
# License(s): apache-2.0
# ...
# 100% 122M/122M [00:01<00:00, 77.1MB/s]
#
# ¡Hecho! Los archivos están en tu Drive.
